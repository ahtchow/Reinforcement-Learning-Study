# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\ad55a\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: pyglet>=1.2.0 in c:\users\ad55a\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\ad55a\anaconda3\lib\site-packages (from gym) (1.18.1)
# Requirement already satisfied: six in c:\users\ad55a\anaconda3\lib\site-packages (from gym) (1.14.0)
# Requirement already satisfied: requests>=2.0 in c:\users\ad55a\anaconda3\lib\site-packages (from gym) (2.22.0)
# Requirement already satisfied: future in c:\users\ad55a\anaconda3\lib\site-packages (from pyglet>=1.2.0->gym) (0.18.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ad55a\anaconda3\lib\site-packages (from requests>=2.0->gym) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ad55a\anaconda3\lib\site-packages (from requests>=2.0->gym) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ad55a\anaconda3\lib\site-packages (from requests>=2.0->gym) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ad55a\anaconda3\lib\site-packages (from requests>=2.0->gym) (3.0.4)

# %%
from agent import Agent
from monitor import interact
import gym
import numpy as np

# %%
env = gym.make('Taxi-v2')
agent = Agent()
avg_rewards, best_avg_reward = interact(env, agent)
# Out:
# [2020-12-07 20:32:09,188] Making new env: Taxi-v2
# Algorithm: sarsa(0)
# Episode 20000/20000 || Best average reward 9.576

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20, 10))
plt.plot(avg_rewards)
plt.show()
