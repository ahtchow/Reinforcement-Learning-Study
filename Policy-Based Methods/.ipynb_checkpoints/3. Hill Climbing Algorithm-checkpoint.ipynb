# %% [markdown]
# # Hill Climbing
#
# ---
#
# In this notebook, we will train hill climbing with adaptive noise scaling with [OpenAI Gym's Cartpole environment](https://gym.openai.com/envs/CartPole-v0/).

# %% [markdown]
# ### Import the Necessary Packages

# %%
import gym
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# !python -m pip install pyvirtualdisplay
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

is_ipython = 'inline' in plt.get_backend()
if is_ipython:
    from IPython import display

plt.ion()
# Out:
# Requirement already satisfied: pyvirtualdisplay in /home/adrian/anaconda3/lib/python3.7/site-packages (1.3.2)
# Requirement already satisfied: EasyProcess in /home/adrian/anaconda3/lib/python3.7/site-packages (from pyvirtualdisplay) (0.3)

# %% [markdown]
# # Define Policy

# %%
env = gym.make('CartPole-v0')
print('observation space:', env.observation_space)
print('Low', env.observation_space.low)
print('High', env.observation_space.high)
print('action space:', env.action_space)
# Out:
# observation space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# Low [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# High [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# action space: Discrete(2)

# %%
class Policy():
    
    def __init__(self, s_size=4, a_size=2):
        
        # weights for simple linear policy: state_space x action_space
        self.weights = 1e-4 * np.random.rand(s_size, a_size)
        
    def forward(self, state):
        
        x = np.dot(state, self.weights)
        return np.exp(x)/sum(np.exp(x))
    
    def act(self, state):
        
        probs = self.forward(state)
        #action = np.random.choice(2, p=probs) # option 1: stochastic policy
        action = np.argmax(probs)              # option 2: deterministic policy
        return action

# %% [markdown]
# ### Train the Agent with Stochastic Policy Search

# %%
env = gym.make('CartPole-v0')
env.seed(0)
np.random.seed(0)

# %%
policy = Policy()

# %%
def hill_climbing(n_episodes=1000, 
                  max_t=1000, 
                  gamma=1.0,
                  print_every=100,
                  noise_scale=1e-2):

    """
    
    Implementation of hill climbing with adaptive noise scaling.
        
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        noise_scale (float): standard deviation of additive noise
    
    """
    
    scores_deque = deque(maxlen=100)
    scores = []
    best_Reward = -np.Inf
    best_weights = policy.weights
    
    for episodes in range(1, n_episodes + 1):
        
        rewards = []
        state = env.reset()
        
        for t in range(max_t):
            
            action = policy.act(state)
            state, reward, done, _ = env.step(action)
            rewards.append(reward)
            
            if done:
                break
        
        scores_deque.append(sum(rewards))
        scores.append(sum(rewards))
        
        discounts = [gamma**i for i in range(len(rewards)+1)]
        Reward = sum([a*b for a,b in zip(discounts, rewards)])
        
        # Found Better Weight
        if Reward >= best_Reward:
            best_Reward = Reward
            best_weights = policy.weights
            
            # This is the noise we are going to add to the weights
            noise_scale = max(1e-3, noise_scale / 2)
            policy.weights += noise_scale * np.random.rand(*policy.weights.shape)
         
        # Did not find better weights
        else:
            
            # Heavier Scaling since we did not find any bigger
            noise_scale = min(2, noise_scale * 2)
            policy.weights = best_weights + (noise_scale * np.random.rand(*policy.weights.shape))
        
            # print('Episode {}\tNoise Scale: {:.2f}'.format(episodes, noise_scale), end='')
            
        if episodes % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(episodes, np.mean(scores_deque)))
            
        if np.mean(scores_deque)>=195.0:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episodes, np.mean(scores_deque)))
            policy.weights = best_weights
            break
        
    return scores

# %% [markdown]
# ### Plot Scores

# %%
scores = hill_climbing()
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 2	Average Score: 35.00
# Episode 3	Average Score: 26.67
# Episode 4	Average Score: 22.00
# Episode 5	Average Score: 19.60
# Episode 7	Average Score: 42.43
# Episode 8	Average Score: 49.00
# Episode 9	Average Score: 54.11
# Episode 11	Average Score: 68.27
# Episode 12	Average Score: 68.92
# Episode 14	Average Score: 81.14
# Episode 15	Average Score: 77.87
# Episode 16	Average Score: 78.69
# Episode 17	Average Score: 82.53
# Episode 18	Average Score: 80.39
# Episode 19	Average Score: 85.42
# Episode 20	Average Score: 86.80
# Episode 22	Average Score: 89.68
# Episode 23	Average Score: 87.13
# Episode 24	Average Score: 84.42
# Episode 25	Average Score: 84.40
# Episode 26	Average Score: 85.77
# Episode 27	Average Score: 85.00
# Episode 28	Average Score: 83.46
# Episode 29	Average Score: 81.28
# Episode 30	Average Score: 79.63
# Episode 31	Average Score: 78.84
# Episode 32	Average Score: 77.59
# Episode 33	Average Score: 76.48
# Episode 34	Average Score: 74.47
# Episode 35	Average Score: 72.60
# Episode 36	Average Score: 72.14
# Episode 37	Average Score: 71.27
# Episode 38	Average Score: 70.42
# Episode 39	Average Score: 69.77
# Episode 40	Average Score: 70.47
# Episode 41	Average Score: 69.56
# Episode 42	Average Score: 68.79
# Episode 43	Average Score: 68.35
# Episode 44	Average Score: 70.09
# Episode 45	Average Score: 69.22
# Episode 46	Average Score: 68.15
# Episode 47	Average Score: 67.74
# Episode 48	Average Score: 66.52
# Episode 49	Average Score: 65.43
# Episode 50	Average Score: 65.14
# Episode 51	Average Score: 65.20
# Episode 52	Average Score: 65.06
# Episode 53	Average Score: 64.02
# Episode 54	Average Score: 63.67
# Episode 55	Average Score: 62.67
# Episode 56	Average Score: 62.86
# Episode 57	Average Score: 62.47
# Episode 58	Average Score: 62.09
# Episode 59	Average Score: 61.25
# Episode 60	Average Score: 61.60
# Episode 61	Average Score: 61.10
# Episode 62	Average Score: 61.15
# Episode 63	Average Score: 60.84
# Episode 64	Average Score: 60.61
# Episode 65	Average Score: 60.38
# Episode 66	Average Score: 61.26
# Episode 67	Average Score: 60.99
# Episode 69	Average Score: 62.26
# Episode 70	Average Score: 61.51
# Episode 71	Average Score: 60.79
# Episode 74	Average Score: 65.28
# Episode 77	Average Score: 69.60
# Episode 80	Average Score: 74.26
# Episode 81	Average Score: 75.17
# Episode 82	Average Score: 76.56
# Episode 83	Average Score: 77.46
# Episode 84	Average Score: 78.79
# Episode 88	Average Score: 83.89
# Episode 92	Average Score: 88.39
# Episode 93	Average Score: 88.75
# Episode 99	Average Score: 94.63
# Episode 100	Average Score: 94.89
# Episode 100	Average Score: 94.89
# Episode 103	Average Score: 99.27
# Episode 105	Average Score: 102.34
# Episode 108	Average Score: 104.54
# Episode 112	Average Score: 107.70
# Episode 115	Average Score: 109.65
# Episode 119	Average Score: 112.44
# Episode 120	Average Score: 112.39
# Episode 123	Average Score: 114.83
# Episode 128	Average Score: 121.42
# Episode 129	Average Score: 122.37
# Episode 134	Average Score: 129.54
# Episode 135	Average Score: 130.46
# Episode 136	Average Score: 131.46
# Episode 139	Average Score: 135.88
# Episode 140	Average Score: 136.44
# Episode 144	Average Score: 140.98
# Episode 145	Average Score: 141.99
# Episode 148	Average Score: 146.25
# Episode 149	Average Score: 147.62
# Episode 151	Average Score: 149.47
# Episode 154	Average Score: 153.63
# Episode 155	Average Score: 154.76
# Episode 159	Average Score: 160.17
# Episode 162	Average Score: 163.51
# Episode 165	Average Score: 167.22
# Episode 169	Average Score: 170.69
# Episode 171	Average Score: 173.72
# Episode 172	Average Score: 172.84
# Episode 174	Average Score: 172.69
# Episode 175	Average Score: 172.63
# Episode 178	Average Score: 173.26
# Episode 180	Average Score: 172.50
# Episode 185	Average Score: 172.79
# Episode 188	Average Score: 172.31
# Episode 190	Average Score: 171.39
# Episode 193	Average Score: 171.77
# Episode 197	Average Score: 170.91
# Episode 199	Average Score: 170.99
# Episode 200	Average Score: 171.78
# Episode 203	Average Score: 171.72
# Episode 209	Average Score: 172.29
# Episode 212	Average Score: 171.81
# Episode 217	Average Score: 171.65
# Episode 223	Average Score: 173.17
# Episode 225	Average Score: 172.24
# Episode 228	Average Score: 171.48
# Episode 230	Average Score: 171.33
# Episode 231	Average Score: 170.29
# Episode 233	Average Score: 169.24
# Episode 234	Average Score: 169.55
# Episode 239	Average Score: 170.40
# Episode 241	Average Score: 169.88
# Episode 242	Average Score: 169.18
# Episode 243	Average Score: 168.31
# Episode 244	Average Score: 168.31
# Episode 246	Average Score: 167.97
# Episode 248	Average Score: 168.76
# Episode 257	Average Score: 171.53
# Episode 263	Average Score: 173.00
# Episode 268	Average Score: 173.06
# Episode 278	Average Score: 176.08
# Episode 280	Average Score: 176.22
# Episode 289	Average Score: 176.96
# Episode 290	Average Score: 176.93
# Episode 295	Average Score: 177.09
# Episode 298	Average Score: 177.03
# Episode 300	Average Score: 177.81
# Episode 303	Average Score: 177.59
# Episode 304	Average Score: 176.69
# Episode 305	Average Score: 175.91
# Episode 306	Average Score: 175.25
# Episode 307	Average Score: 174.27
# Episode 311	Average Score: 174.64
# Episode 318	Average Score: 175.48
# Episode 321	Average Score: 174.90
# Episode 324	Average Score: 174.92
# Episode 325	Average Score: 174.99
# Episode 328	Average Score: 175.00
# Episode 331	Average Score: 176.30
# Episode 332	Average Score: 175.85
# Episode 333	Average Score: 175.87
# Episode 335	Average Score: 175.92
# Episode 342	Average Score: 177.48
# Episode 343	Average Score: 177.59
# Episode 344	Average Score: 177.74
# Episode 345	Average Score: 176.98
# Episode 346	Average Score: 176.93
# Episode 349	Average Score: 176.18
# Episode 350	Average Score: 175.28
# Episode 359	Average Score: 174.50
# Episode 362	Average Score: 173.42
# Episode 363	Average Score: 172.96
# Episode 366	Average Score: 172.49
# Episode 370	Average Score: 172.60
# Episode 371	Average Score: 171.73
# Episode 372	Average Score: 171.23
# Episode 374	Average Score: 170.37
# Episode 376	Average Score: 169.71
# Episode 379	Average Score: 169.71
# Episode 380	Average Score: 169.65
# Episode 381	Average Score: 168.67
# Episode 386	Average Score: 167.71
# Episode 387	Average Score: 166.99
# Episode 389	Average Score: 167.01
# Episode 391	Average Score: 167.75
# Episode 396	Average Score: 167.85
# Episode 400	Average Score: 167.84
# Episode 400	Average Score: 167.84
# Episode 405	Average Score: 169.60
# Episode 406	Average Score: 169.28
# Episode 409	Average Score: 169.42
# Episode 411	Average Score: 169.07
# Episode 412	Average Score: 168.21
# Episode 413	Average Score: 167.29
# Episode 415	Average Score: 166.39
# Episode 416	Average Score: 166.09
# Episode 421	Average Score: 167.57
# Episode 423	Average Score: 166.54
# Episode 426	Average Score: 167.28
# Episode 427	Average Score: 166.53
# Episode 428	Average Score: 166.59
# Episode 429	Average Score: 165.77
# Episode 430	Average Score: 165.11
# Episode 433	Average Score: 166.53
# Episode 435	Average Score: 166.67
# Episode 436	Average Score: 165.75
# Episode 443	Average Score: 166.76
# Episode 446	Average Score: 168.25
# Episode 447	Average Score: 167.47
# Episode 451	Average Score: 168.45
# Episode 452	Average Score: 168.21
# Episode 456	Average Score: 167.33
# Episode 457	Average Score: 166.49
# Episode 459	Average Score: 166.67
# Episode 460	Average Score: 165.88
# Episode 464	Average Score: 166.92
# Episode 466	Average Score: 166.61
# Episode 470	Average Score: 166.56
# Episode 473	Average Score: 166.97
# Episode 476	Average Score: 168.10
# Episode 485	Average Score: 169.72
# Episode 489	Average Score: 171.65
# Episode 497	Average Score: 171.86
# Episode 500	Average Score: 172.79
# Episode 501	Average Score: 171.81
# Episode 503	Average Score: 170.79
# Episode 507	Average Score: 172.23
# Episode 510	Average Score: 172.13
# Episode 511	Average Score: 172.28
# Episode 514	Average Score: 173.39
# Episode 516	Average Score: 173.75
# Episode 518	Average Score: 173.03
# Episode 522	Average Score: 172.36
# Episode 523	Average Score: 172.70
# Episode 526	Average Score: 172.93
# Episode 527	Average Score: 172.70
# Episode 532	Average Score: 174.21
# Episode 534	Average Score: 174.45
# Episode 535	Average Score: 174.16
# Episode 537	Average Score: 174.20
# Episode 538	Average Score: 173.20
# Episode 539	Average Score: 172.32
# Episode 545	Average Score: 172.47
# Episode 546	Average Score: 172.73
# Episode 548	Average Score: 172.51
# Episode 551	Average Score: 172.45
# Episode 556	Average Score: 172.63
# Episode 557	Average Score: 172.71
# Episode 560	Average Score: 173.54
# Episode 566	Average Score: 174.58
# Episode 568	Average Score: 174.16
# Episode 574	Average Score: 175.22
# Episode 575	Average Score: 174.21
# Episode 580	Average Score: 174.57
# Episode 586	Average Score: 174.53
# Episode 588	Average Score: 173.69
# Episode 593	Average Score: 173.64
# Episode 594	Average Score: 173.08
# Episode 595	Average Score: 172.34
# Episode 599	Average Score: 172.17
# Episode 600	Average Score: 172.17
# Episode 602	Average Score: 172.41
# Episode 603	Average Score: 173.20
# Episode 604	Average Score: 172.32
# Episode 608	Average Score: 171.99
# Episode 609	Average Score: 171.17
# Episode 611	Average Score: 172.50
# Episode 613	Average Score: 171.58
# Episode 618	Average Score: 173.22
# Episode 623	Average Score: 173.60
# Episode 627	Average Score: 174.45
# Episode 629	Average Score: 173.42
# Episode 632	Average Score: 173.32
# Episode 633	Average Score: 172.28
# Episode 636	Average Score: 173.09
# Episode 639	Average Score: 175.68
# Episode 642	Average Score: 174.76
# Episode 645	Average Score: 174.46
# Episode 646	Average Score: 174.50
# Episode 649	Average Score: 174.79
# Episode 657	Average Score: 176.51
# Episode 662	Average Score: 176.26
# Episode 664	Average Score: 175.48
# Episode 665	Average Score: 174.46
# Episode 666	Average Score: 174.14
# Episode 667	Average Score: 173.42
# Episode 670	Average Score: 172.92
# Episode 672	Average Score: 172.88
# Episode 674	Average Score: 172.83
# Episode 675	Average Score: 172.94
# Episode 676	Average Score: 172.20
# Episode 678	Average Score: 171.26
# Episode 685	Average Score: 170.39
# Episode 688	Average Score: 171.21
# Episode 689	Average Score: 170.27
# Episode 690	Average Score: 169.77
# Episode 692	Average Score: 169.03
# Episode 696	Average Score: 170.45
# Episode 697	Average Score: 169.61
# Episode 700	Average Score: 170.42
# Episode 701	Average Score: 169.47
# Episode 704	Average Score: 170.46
# Episode 710	Average Score: 172.10
# Episode 711	Average Score: 171.72
# Episode 714	Average Score: 171.88
# Episode 716	Average Score: 171.00
# Episode 717	Average Score: 170.62
# Episode 719	Average Score: 170.36
# Episode 720	Average Score: 169.64
# Episode 722	Average Score: 168.79
# Episode 724	Average Score: 168.96
# Episode 726	Average Score: 168.27
# Episode 728	Average Score: 168.51
# Episode 730	Average Score: 168.84
# Episode 732	Average Score: 168.70
# Episode 733	Average Score: 168.84
# Episode 735	Average Score: 168.09
# Episode 738	Average Score: 168.03
# Episode 739	Average Score: 167.26
# Episode 740	Average Score: 166.73
# Episode 748	Average Score: 168.51
# Episode 749	Average Score: 168.54
# Episode 750	Average Score: 167.63
# Episode 757	Average Score: 167.79
# Episode 758	Average Score: 167.15
# Episode 760	Average Score: 166.41
# Episode 761	Average Score: 165.87
# Episode 762	Average Score: 165.90
# Episode 767	Average Score: 168.88
# Episode 768	Average Score: 167.98
# Episode 772	Average Score: 168.14
# Episode 774	Average Score: 168.20
# Episode 776	Average Score: 169.76
# Episode 777	Average Score: 168.78
# Episode 778	Average Score: 168.73
# Episode 780	Average Score: 167.89
# Episode 782	Average Score: 167.11
# Episode 784	Average Score: 166.23
# Episode 787	Average Score: 166.71
# Episode 794	Average Score: 168.95
# Episode 795	Average Score: 168.94
# Episode 796	Average Score: 168.72
# Episode 798	Average Score: 168.73
# Episode 799	Average Score: 168.33
# Episode 800	Average Score: 168.33
# Episode 809	Average Score: 169.36
# Episode 810	Average Score: 168.57
# Episode 812	Average Score: 169.09
# Episode 813	Average Score: 168.28
# Episode 816	Average Score: 169.18
# Episode 817	Average Score: 168.59
# Episode 824	Average Score: 171.21
# Episode 826	Average Score: 171.04
# Episode 828	Average Score: 170.82
# Episode 830	Average Score: 170.68
# Episode 834	Average Score: 171.58
# Episode 835	Average Score: 171.45
# Episode 837	Average Score: 170.67
# Episode 839	Average Score: 171.37
# Episode 840	Average Score: 171.03
# Episode 844	Average Score: 170.22
# Episode 845	Average Score: 169.38
# Episode 854	Average Score: 170.81
# Episode 855	Average Score: 169.84
# Episode 856	Average Score: 169.02
# Episode 862	Average Score: 171.66
# Episode 864	Average Score: 170.66
# Episode 869	Average Score: 171.12
# Episode 870	Average Score: 170.39
# Episode 874	Average Score: 171.50
# Episode 876	Average Score: 170.92
# Episode 877	Average Score: 171.57
# Episode 879	Average Score: 171.68
# Episode 881	Average Score: 171.80
# Episode 883	Average Score: 172.35
# Episode 884	Average Score: 173.00
# Episode 893	Average Score: 172.49
# Episode 894	Average Score: 172.53
# Episode 899	Average Score: 173.67
# Episode 900	Average Score: 173.67
# Episode 901	Average Score: 172.87
# Episode 902	Average Score: 172.11
# Episode 910	Average Score: 172.99
# Episode 913	Average Score: 173.58
# Episode 914	Average Score: 172.92
# Episode 916	Average Score: 172.96
# Episode 917	Average Score: 173.03
# Episode 919	Average Score: 172.51
# Episode 920	Average Score: 171.53
# Episode 921	Average Score: 170.68
# Episode 922	Average Score: 169.74
# Episode 926	Average Score: 170.50
# Episode 927	Average Score: 169.50
# Episode 934	Average Score: 172.00
# Episode 935	Average Score: 171.86
# Episode 936	Average Score: 171.24
# Episode 937	Average Score: 171.16
# Episode 938	Average Score: 170.13
# Episode 939	Average Score: 170.33
# Episode 942	Average Score: 170.28
# Episode 944	Average Score: 170.88
# Episode 945	Average Score: 171.02
# Episode 946	Average Score: 170.22
# Episode 954	Average Score: 170.17
# Episode 956	Average Score: 171.37
# Episode 957	Average Score: 171.28
# Episode 958	Average Score: 170.36
# Episode 959	Average Score: 169.50
# Episode 960	Average Score: 168.59
# Episode 962	Average Score: 168.69
# Episode 965	Average Score: 169.00
# Episode 967	Average Score: 168.74
# Episode 968	Average Score: 167.78
# Episode 971	Average Score: 168.66
# Episode 972	Average Score: 167.99
# Episode 973	Average Score: 167.27
# Episode 976	Average Score: 167.66
# Episode 983	Average Score: 168.86
# Episode 984	Average Score: 168.08
# Episode 988	Average Score: 167.27
# Episode 991	Average Score: 166.59
# Episode 994	Average Score: 167.45
# Episode 995	Average Score: 166.46
# Episode 999	Average Score: 166.80
# Episode 1000	Average Score: 165.83
# Episode 1000	Average Score: 165.83
